# %%
from operator import add
from pyspark.ml.feature import RegexTokenizer, CountVectorizer
from pyspark.ml.feature import StopWordsRemover, VectorAssembler
from pyspark.ml.feature import Word2Vec, Word2VecModel
from pyspark.ml.feature import IDF
from pyspark.ml import Pipeline, PipelineModel

from pyspark.sql.functions import *
from pyspark.sql.types import *

from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
#sc = SparkContext(gateway = jg.launch_gateway())

import folium
import html

import pandas as pd
import numpy as np

# %%
data_path = '/Volumes/Transcend/dataset/'
model_path = '/Volumes/Transcend/MDS_Yelp/model/'
outout_path = '/Volumes/Transcend/MDS_Yelp/output/'

# %% [markdown]
# If spark jobs fail, stop the existing service and restart

# %%
sc.stop()

# %%
sc = SparkContext()
#sc = SparkContext('local')
spark = SparkSession(sc)

# %%
business_df = spark.read.parquet(data_path + 'business-small.parquet')
business_df.printSchema()
# Out:
# root
#  |-- business_id: string (nullable = true)
#  |-- business_name: string (nullable = true)
#  |-- neighborhood: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- categories: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
user_df = spark.read.parquet(data_path + 'user-small.parquet')
user_df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- yelping_since: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- fans: long (nullable = true)
#  |-- average_stars: double (nullable = true)

# %%
review_df = spark.read.parquet(data_path + 'review-small.parquet')
review_df.printSchema()
# Out:
# root
#  |-- review_id: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- stars: long (nullable = true)
#  |-- review_date: string (nullable = true)
#  |-- review_text: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- cool: long (nullable = true)

# %%
# create SQL view for later queries
review_df.createOrReplaceTempView("reviews")

# create review text dataframe
reviews_text = spark.sql("SELECT user_id, review_text FROM reviews")
reviews_text.show(3)
# Out:
# +--------------------+--------------------+
# |             user_id|         review_text|
# +--------------------+--------------------+
# |u0LXt3Uea_GidxRW1...|Who would have gu...|
# |u0LXt3Uea_GidxRW1...|Not bad!! Love th...|
# |u0LXt3Uea_GidxRW1...|This is currently...|
# +--------------------+--------------------+
# only showing top 3 rows

# %%
# concatenate all reviews per restuarant

reviews_text_rdd = reviews_text.rdd
reviews_by_user_rdd = reviews_text_rdd.map(tuple).reduceByKey(add)  
reviews_by_user_df = spark.createDataFrame(reviews_by_user_rdd)
reviews_by_user_df = reviews_by_user_df \
                            .withColumnRenamed('_1', 'user_id') \
                            .withColumnRenamed('_2', 'text')
reviews_by_user_df.count()
# Out:
# 73041

# %% [markdown]
# #### Sample example of how word2vec works

# %%
## Example of using Word2vec
from pyspark.ml.feature import Word2Vec

# Input data: Each row is a bag of words from a sentence or document.
documentDF = spark.createDataFrame([
    ("Hi I heard about Spark".split(" "), ),
    ("I wish Java could use case classes".split(" "), ),
    ("Logistic regression models are neat".split(" "), )
], ["text"])

# Learn a mapping from words to Vectors.
word2Vec = Word2Vec(vectorSize=3, minCount=0, inputCol="text", outputCol="result")
model = word2Vec.fit(documentDF)

result = model.transform(documentDF)
for row in result.collect():
    text, vector = row
    print("Text: [%s] => \nVector: %s\n" % (", ".join(text), str(vector)))
# Out:
# Text: [Hi, I, heard, about, Spark] =>
# Vector: [0.02326762331649661,0.008931299671530724,-0.06394885405898094]
#
# Text: [I, wish, Java, could, use, case, classes] =>
# Vector: [-0.009175857529044151,-0.024911361613443917,0.012272004171141555]
#
# Text: [Logistic, regression, models, are, neat] =>
# Vector: [-0.005160079896450043,-0.0005152661353349686,0.014656295813620091]

# %%
## https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.feature.Word2Vec

## The minimum number of times a token must appear to be included in the word2vec model's vocabulary"

# %%
# %%time
# usefule link: https://www.tutorialkart.com/apache-spark/spark-mllib-tf-idf/
# create text processing pipeline -- this a lengthy resource-intensive process
# Build the pipeline 
regexTokenizer = RegexTokenizer(gaps = False, pattern = '\w+', inputCol = 'text', outputCol = 'token')
stopWordsRemover = StopWordsRemover(inputCol = 'token', outputCol = 'nostopwrd')
countVectorizer = CountVectorizer(inputCol="nostopwrd", outputCol="rawFeature")
iDF = IDF(inputCol="rawFeature", outputCol="idf_vec")
# TD-IDF Vec
word2Vec = Word2Vec(vectorSize = 100, minCount = 5, inputCol = 'nostopwrd', outputCol = 'word_vec', seed=123)
vectorAssembler = VectorAssembler(inputCols=['idf_vec', 'word_vec'], outputCol='comb_vec')
pipeline = Pipeline(stages=[regexTokenizer, stopWordsRemover, countVectorizer, iDF, word2Vec, vectorAssembler])

# fit the model
pipeline_mdl = pipeline.fit(reviews_by_user_df)

#save the pipeline model
pipeline_mdl.write().overwrite().save(model_path + 'pipe_txt')

# %%
# load the text transformation pipeline trained model
pipeline_mdl = PipelineModel.load(model_path + 'pipe_txt')

# %%
# transform the review data
reviews_by_user_trf_df = pipeline_mdl.transform(reviews_by_user_df)

# %%
# show the transformed review data
reviews_by_user_trf_df.select( 'text', 'nostopwrd', 'idf_vec', 'word_vec').show(10)
# Out:
# +--------------------+--------------------+--------------------+--------------------+
# |                text|           nostopwrd|             idf_vec|            word_vec|
# +--------------------+--------------------+--------------------+--------------------+
# |A born and bred T...|[born, bred, toro...|(128365,[0,1,2,3,...|[-0.0298230579082...|
# |I have never done...|[never, done, one...|(128365,[2,6,11,1...|[-0.0256846508636...|
# |What a find!  I'm...|[find, m, almost,...|(128365,[2,3,6,11...|[-0.0783052189961...|
# |Not impressed wit...|[impressed, place...|(128365,[0,1,2,3,...|[-0.0273270801487...|
# |Very tight space....|[tight, space, fo...|(128365,[2,39,116...|[-0.0261619807634...|
# |While in Toronto ...|[toronto, last, w...|(128365,[0,1,2,3,...|[-0.0836421314076...|
# |I loved the decor...|[loved, decor, re...|(128365,[0,1,3,5,...|[-0.0428024260223...|
# |Amazing vermacell...|[amazing, vermace...|(128365,[0,2,4,5,...|[-0.1015487008305...|
# |Uncle Tetsu's is ...|[uncle, tetsu, ho...|(128365,[0,1,2,4,...|[-0.0397153475544...|
# |Love this place! ...|[love, place, eve...|(128365,[0,1,2,3,...|[0.00909978398385...|
# +--------------------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
def CosineSim(vec1, vec2): 
    return np.dot(vec1, vec2) / np.sqrt(np.dot(vec1, vec1)) / np.sqrt(np.dot(vec2, vec2))

# %%
all_user_vecs = reviews_by_user_trf_df.select('user_id', 'word_vec').rdd.map(lambda x: (x[0], x[1])).collect()

# %% [raw]
# def toCSVLine(data):
#     return(','.join(str(d) for d in data))
#
# lines = rdd_odj.map(toCSVLine)
# lines.saveAsTextFile('rdd_file_to_csv.csv')

# %% [raw]
# import pickle
#
# #with open("all_user_vecs.txt", "wb") as fp:   #Pickling
# #    pickle.dump(all_user_vecs, fp)
#
# with open("all_user_vecs.txt", "rb") as fp:   # Unpickling
#     all_user_vecs = pickle.load(fp)

# %%
all_user_vecs[0]
# user_id = 'nOTl4aPC4tKHK35T3bNauQ'
# DenseVector() - vector respresentation of all the reviews of User
# Out:
# ('BytRWk8X1OelSgwwfXd8Aw',
#  DenseVector([-0.0298, -0.0741, -0.0649, 0.0832, 0.0279, -0.0149, -0.0436, -0.0123, -0.0076, -0.0379, -0.0085, -0.0369, -0.0037, -0.0116, 0.0142, -0.0317, -0.0555, -0.0272, -0.0729, 0.0104, -0.0666, -0.0442, 0.0158, 0.0029, 0.0563, -0.0458, -0.0137, -0.0207, -0.0063, 0.0337, 0.0583, 0.0148, 0.0212, -0.0019, -0.031, -0.0436, 0.0617, 0.0352, -0.0151, -0.0433, -0.0319, -0.0212, -0.0246, 0.0944, 0.0214, -0.0364, -0.0363, 0.0447, 0.0029, 0.0008, 0.0107, -0.0229, -0.0219, -0.045, -0.0714, 0.0296, 0.0166, 0.0181, 0.0324, -0.0024, -0.0046, 0.0065, 0.0301, -0.049, -0.0385, 0.0413, 0.0566, 0.0437, -0.0322, 0.0902, -0.0098, -0.0056, 0.0242, 0.0346, 0.0133, -0.0412, -0.0373, 0.0083, -0.0207, 0.0461, -0.0175, -0.0269, 0.0018, -0.0071, -0.0001, 0.0023, 0.0449, 0.0108, 0.0087, 0.0074, 0.013, -0.0001, -0.0442, 0.0266, -0.0158, -0.0175, -0.0496, 0.0423, -0.0899, 0.034]))

# %%
def getSimilarUsers(u_ids, all_user_vecs, sim_user_limit=10):
    
    schema = StructType([   
                            StructField("user_id", StringType(), True)
                            ,StructField("score", IntegerType(), True)
                            ,StructField("input_user_id", StringType(), True)
                        ])
    
    similar_user_df = spark.createDataFrame([], schema)
    similar_user_df_all = spark.createDataFrame([], schema)
    
    for u_id in u_ids:
        input_vec = [(r[1]) for r in all_user_vecs if r[0] == u_id]
        if(len(input_vec) < 1):
            print("not in the user_df")
            break
        else:
            #print("-------------------------------")
            #print(u_id)
            input_vec = input_vec[0]
    
        similar_user_rdd = sc.parallelize((i[0], float(CosineSim(input_vec, i[1]))) for i in all_user_vecs)
        
        similar_user_df = spark.createDataFrame(similar_user_rdd) \
            .withColumnRenamed('_1', 'user_id') \
            .withColumnRenamed('_2', 'score') \
            .orderBy("score", ascending = False)
            
        similar_user_df = similar_user_df.dropna()    
        similar_user_df = similar_user_df.filter(col("user_id") != u_id).limit(sim_user_limit)
        similar_user_df = similar_user_df.withColumn('input_user_id', lit(u_id))
        
        similar_user_df = similar_user_df \
                                    .union(similar_user_df)
        
        similar_user_df_all = similar_user_df_all.union(similar_user_df)
    similar_user_df_all = similar_user_df_all.dropDuplicates()    
    return similar_user_df_all

# %%
def getUserDetails(user):
    
    a = user.alias("a")
    b = user_df.alias("b")
    
    return a.join(b, col("a.user_id") == col("b.user_id"), 'inner') \
             .select([col('a.'+xx) for xx in a.columns] + [col('b.user_id'), col('b.user_name'),col('b.review_count')])

# %%
# test with two users

uids = ['nOTl4aPC4tKHK35T3bNauQ', 'QBac9-Ii6jR-yLsQ5MVTHg']

print('\ninput user details:')
user_df.select('user_id','user_name', 'review_count') \
    .filter(user_df.user_id.isin(uids) == True).show(truncate=False)
    
# get top 10 similar users
sim_users = getUserDetails(getSimilarUsers(uids, all_user_vecs, 10))

print('Top 10 similar Users for each input restaurant are:"')
sim_users_df = sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas()
sim_users_df
# Out:
# input user details:
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |nOTl4aPC4tKHK35T3bNauQ|Katherine|148         |
# |QBac9-Ii6jR-yLsQ5MVTHg|Alex     |13          |
# +----------------------+---------+------------+
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# Top 10 similar Users for each input restaurant are:"
#              input_user_id                 user_id user_name     score  \
# 0   QBac9-Ii6jR-yLsQ5MVTHg  J5Eb7LhJaOa20k0ppcOCOg      Alek  0.907664
# 1   nOTl4aPC4tKHK35T3bNauQ  ZBllYKrFzaI0I7v6Wl26Wg   Cecilia  0.963999
# 2   QBac9-Ii6jR-yLsQ5MVTHg  cNhHuEQMIpLH_qc9qGz67A       Jay  0.910774
# 3   QBac9-Ii6jR-yLsQ5MVTHg  _IR48ok0ZkPMWJ2PlRCk0A   Michael  0.907098
# 4   nOTl4aPC4tKHK35T3bNauQ  myrcQ3h2G04Gv-ANG_oqrg     Linda  0.971381
# 5   QBac9-Ii6jR-yLsQ5MVTHg  MpN81tQOL86GaFse-_tTRQ       Amy  0.913263
# 6   QBac9-Ii6jR-yLsQ5MVTHg  kw-YtOKPXrRB2a9wRZlmzQ     Jimmy  0.915453
# 7   nOTl4aPC4tKHK35T3bNauQ  uO1w3qNo21c1bVHHFTYW0w    Joanne  0.972255
# 8   QBac9-Ii6jR-yLsQ5MVTHg  bPUpO-bP6BmAGvSwPyDsng   Michael  0.905848
# 9   nOTl4aPC4tKHK35T3bNauQ  PGx4HvY5joEeqXzam6tO7A      Lisa  0.965808
# 10  nOTl4aPC4tKHK35T3bNauQ  VVm-TFCpi9M1-k8ED0l1eA   Juliana  0.971013
# 11  QBac9-Ii6jR-yLsQ5MVTHg  xcBcIMVWEx1p7V8ACaeHpQ      Rick  0.918668
# 12  nOTl4aPC4tKHK35T3bNauQ  yL60onlTh1BmJKVLli_K3g  Danielle  0.964604
# 13  nOTl4aPC4tKHK35T3bNauQ  vJGLEHyhCs9V-5fAe-xx3w      Lisa  0.968622
# 14  nOTl4aPC4tKHK35T3bNauQ  v1nRL_f2EQs7fjh_m0TdQQ     Bryan  0.969187
# 15  nOTl4aPC4tKHK35T3bNauQ  n4usc2DF4pd9fdi2wLDloQ    Lidiya  0.964592
# 16  QBac9-Ii6jR-yLsQ5MVTHg  g5W7s0n19gvT1Ujy_ITJog      Bria  0.907846
# 17  nOTl4aPC4tKHK35T3bNauQ  USUw_VT31ygQ9JkEc6nPsg        NJ  0.965363
# 18  QBac9-Ii6jR-yLsQ5MVTHg  eV5usRjY2cDqNKVv8wXroA       Sam  0.905077
# 19  QBac9-Ii6jR-yLsQ5MVTHg  zkKv10FEw-iWJBHvK0mGfA      Paul  0.903733
#
#     review_count
# 0             34
# 1            135
# 2             57
# 3             82
# 4            112
# 5             46
# 6            101
# 7            221
# 8            142
# 9            349
# 10           442
# 11            83
# 12           264
# 13           334
# 14            33
# 15           343
# 16            73
# 17            90
# 18           105
# 19            55

# %% [raw]
# pd_review_df = review_df.toPandas()

# %%
review = pd.read_csv("/Volumes/Transcend/MDS_Yelp/yelp_review.csv")

# %%
#uids = ['nOTl4aPC4tKHK35T3bNauQ', 'QBac9-Ii6jR-yLsQ5MVTHg']
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['PGx4HvY5joEeqXzam6tO7A'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] 
#average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  cefRDEK5O3t_iUuwnmL27Q        4        3
# 1  pOEL97ld-FJMKO8Ki8JmYg        3        5
# 2  EjZYT46Y2qHSoChynd0q-A        4        5
# 3  _vZ7bHaGCjllogiZ7RH17w        3        4
# 4  JPgBO-7imIPdc2XBkvynpQ        4        4
# 5  S5bNE4Pmin8OQUMOFod8bQ        3        2
# 6  uF86ZhygpBEGr3CudNemYA        3        3
# 7  RkekriZhaIZ7nSJBVept6Q        4        4
#
#                                               text_x  \
# 0  We booked a reservation at Smith for Summerlic...
# 1  Okay, so my rating has gone down from the firs...
# 2  This small gallery is a bit hard to get to at ...
# 3  My sister told me that Origin was well known f...
# 4  For some reason when I heard the name of this ...
# 5  I actually think this restaurant deserves a 3-...
# 6  When deciding where to go to Valentine's Day d...
# 7  I really wanted to be blown away by this place...
#
#                                               text_y      date_x      date_y
# 0  This place looks small from the outside, but i...  2012-07-12  2016-07-31
# 1  I am a big fan of anything Oliver & Bonacini. ...  2013-10-20  2013-01-13
# 2  I love this place.  I stumbled on it when my b...  2012-11-11  2014-10-03
# 3  4.5 stars \n\nI came here with a girl friend  ...  2014-04-02  2015-04-06
# 4  Huge, huge list of Martinis.  Prices aren't ba...  2011-03-21  2015-01-03
# 5  Came here with a girl friend for dinner on a F...  2011-07-17  2012-10-28
# 6  I'm terrified of the dark and it took me a lon...  2011-11-20  2012-04-10
# 7  I've wanted to try this place for awhile and f...  2013-02-16  2012-09-23

# %%
import fastparquet
review_df = pd.read_parquet(data_path + 'review-small.parquet', engine='fastparquet')

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['vJGLEHyhCs9V-5fAe-xx3w'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  oQylTvXwGIkKFdCjmafKVg        4        4
# 1  5N8R7ALESZ30EoAzVJtabw        5        5
# 2  u2ETlHOcFdRz4BxcdfsK0Q        3        3
#
#                                               text_x  \
# 0  We went here after dinner, simply for drinks. ...
# 1  Went in on a whim and was not disappointed. I ...
# 2  We went here for Summerlicious. For $25 we got...
#
#                                               text_y      date_x      date_y
# 0  We came here for Mother's day as has become tr...  2013-02-10  2013-06-04
# 1  The Dirty Bird invited me back to give them an...  2016-10-17  2015-10-15
# 2  I came here for a ladies lunch with the girls ...  2012-07-08  2013-06-04

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['ZBllYKrFzaI0I7v6Wl26Wg'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  cefRDEK5O3t_iUuwnmL27Q        4        4
# 1  c78Pat78fVUBFPXYeVvbaQ        5        3
#
#                                               text_x  \
# 0  We booked a reservation at Smith for Summerlic...
# 1  I am surprised at the people complaining about...
#
#                                               text_y      date_x      date_y
# 0  I would've given it 5 stars for the food, but ...  2012-07-12  2014-05-05
# 1  Overrated. \n\nMistake: coming to Odd Seoul on...  2016-01-24  2016-03-01

# %%
review_uid1 = review.loc[review['user_id'].isin(['nOTl4aPC4tKHK35T3bNauQ'])]
review_uid2 = review.loc[review['user_id'].isin(['VVm-TFCpi9M1-k8ED0l1eA'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  zgQHtqX0gqMw1nlBZl2VnQ        2        4
# 1  kGOr_D-LNpgZ2M9N8TT4QQ        5        4
# 2  W5d8iNog90R-qw43m5dGwg        5        5
# 3  OIdOJaNS8M624F58XGV3PQ        4        3
#
#                                               text_x  \
# 0  While I really enjoyed the noodles, their sign...
# 1  I went here with my husband and another couple...
# 2  I have been craving schnitzel for a LONG time,...
# 3  Really this deserves a 3-1\/2 star rating, but...
#
#                                               text_y      date_x      date_y
# 0  Actual rating 3.5\n\nLet's get my main gripe o...  2013-10-19  2014-11-22
# 1  La Societe looks as good as you'd imagine a re...  2013-01-27  2012-01-05
# 2  Had lunch here today and I'm totally sold.  Si...  2012-10-08  2012-08-12
# 3  Actually around 3.5\n\nHaven't been here in qu...  2012-11-11  2014-12-22

# %%
review_uid1 = review.loc[review['user_id'].isin(['QBac9-Ii6jR-yLsQ5MVTHg'])]
review_uid2 = review.loc[review['user_id'].isin(['eV5usRjY2cDqNKVv8wXroA'])]
merged_uid = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
merged_uid[['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']] #average the rating if more than 1 review
# Out:
#               business_id  stars_x  stars_y  \
# 0  r_BrIgzYcwo1NAuG9dLbpg        4        3
#
#                                               text_x  \
# 0  This review will be shorter than my first two....
#
#                                               text_y      date_x      date_y
# 0  Total cheap eat hipster restaurant. The food w...  2016-07-05  2016-05-02

# %% [markdown]
# ##### Top users based on review count

# %%
# converting to pandas dataframe
user_pd = user_df.toPandas()
user_pd = user_pd.sort_values(by = 'review_count', ascending= False)
uids_top_500 = list(user_pd.user_id.iloc[0:500])
user_pd.head()
# Out:
#                       user_id user_name  review_count yelping_since  useful  \
# 54601  8RcEwGrFIgkt9WQ35E6SnQ    George          7764    2009-11-06     123
# 44835  Xwnf20FKuikiHcSpcEbpKQ   Kenneth          6653    2011-06-10    1444
# 22639  CxDOIDnH8gp9KXzpBHJYXw  Jennifer          5868    2009-11-09    1241
# 48114  HFECrzYDpgbS5EmTBtj2zQ      Eric          5344    2007-03-28    3905
# 29361  Hi10sGSZNxQH3NLyWSZ1oA       Fox          4537    2009-05-26   40103
#
#        funny   cool  fans  average_stars
# 54601    139    113   272           3.49
# 44835   1142   1167   237           3.32
# 22639   1968    959   610           3.29
# 48114   3876   3847   397           3.93
# 29361  40030  39837   871           3.81

# %% [markdown]
# ##### Find similarity for top 500 users (count of reviews)

# %%
sim_users_all = pd.DataFrame(columns = ['input_user_id', 'user_id', 'user_name', 'score', 'review_count'])

# %%
iterator = 0
for uid in uids_top_500[250:400]:
    user_df.select('user_id','user_name', 'review_count') \
            .filter(user_df.user_id.isin([uid]) == True).show(truncate=False)

    sim_users = getUserDetails(getSimilarUsers([uid], all_user_vecs, 10))
    sim_users_pd = sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas()
    sim_users_all = pd.concat([sim_users_all, sim_users_pd])
    sim_users_all = sim_users_all.drop_duplicates()
    sim_users_all = sim_users_all.sort_values(by = 'input_user_id')
    iterator = iterator + 1
    print(iterator)
    #if iterator > 20:
    #   sim_users_all.to_csv("sim_users_200.csv")

with open("sim_users_250_400.txt", "wb") as fp:   #Pickling
    pickle.dump(sim_users_all, fp)

sim_users_all.to_csv("sim_users_250_400.csv")
# Out:
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |s19c8t_yAmFrby90LjDk8g|Jason    |940         |
# +----------------------+---------+------------+
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# 1
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |GGSfLyM88SbFGhnm46ykXQ|Coco     |938         |
# +----------------------+---------+------------+
#
# 2
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |rqY0AQMUtoDQnfgxCNuKgw|Dan      |931         |
# +----------------------+---------+------------+
#
# 3
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |j6wLUT0ZXi-x0otelYIFpA|Elaine   |930         |
# +----------------------+---------+------------+
#
# 4
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |r-Ck0JPoMfHI7h2X0brm2w|Rashid   |926         |
# +----------------------+---------+------------+
#
# 5
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |l0MBP2olaZc5_SP5nWTCWg|R        |922         |
# +----------------------+---------+------------+
#
# 6
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |kkPgJv6KBFN15caG7NYYlg|Ali      |921         |
# +----------------------+---------+------------+
#
# 7
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |eSU_HjKOA3Ppt8oS07oYkw|Eric     |916         |
# +----------------------+---------+------------+
#
# 8
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |eBbIYdWMsnDd3b5n84TfSw|Krys     |916         |
# +----------------------+---------+------------+
#
# 9
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |1pzP58PeWictHQzctMU0nQ|Misty    |915         |
# +----------------------+---------+------------+
#
# 10
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |V4uH52BfO596yG7OAn5w-A|Albert   |913         |
# +----------------------+---------+------------+
#
# 11
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |dIQnYbjf-rTxn5dQoRr0bg|Kristen  |907         |
# +----------------------+---------+------------+
#
# 12
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |QSA05SquUKJZnxasypxvjg|.        |904         |
# +----------------------+---------+------------+
#
# 13
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |q6XnQNNOEgvZaeizUgHTSw|Mike     |900         |
# +----------------------+---------+------------+
#
# 14
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |H4EQn0rjFuGRgIm6c9NFLg|Jeff     |897         |
# +----------------------+---------+------------+
#
# 15
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |sZxXpvmBUN2fSCtK_BZFoQ|Dane     |896         |
# +----------------------+---------+------------+
#
# 16
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |KDewJBJknfWvQyHHFNbfdg|Jon      |893         |
# +----------------------+---------+------------+
#
# 17
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |RylA6VZUTRuMGBu4nHKbCw|Ben      |892         |
# +----------------------+---------+------------+
#
# 18
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |qlTwCtl1aqctl-Kw2CRQ5Q|Tina     |892         |
# +----------------------+---------+------------+
#
# 19
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |n31zWKg821H9iC8UDlQ-MQ|Kevin    |887         |
# +----------------------+---------+------------+
#
# 20
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |h9MZv5I1hvTX1kkzq-3Cvg|Erin     |887         |
# +----------------------+---------+------------+
#
# 21
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |hj7o_BPgj-HdLAxdKqdx-w|Breanna  |887         |
# +----------------------+---------+------------+
#
# 22
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |vASaF47nWvCHEEDA8nfCVw|Ange     |887         |
# +----------------------+---------+------------+
#
# 23
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |-B-QEUESGWHPE_889WJaeg|Mark     |882         |
# +----------------------+---------+------------+
#
# 24
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |iuoWUmvleAusz0_T5iHNHg|Chelsy   |881         |
# +----------------------+---------+------------+
#
# 25
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |65qbB9h_uLvS5JTiC-g-0A|Sasha    |881         |
# +----------------------+---------+------------+
#
# 26
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |pEMWzZ8qWY1T_K0HUoKDIA|Hope     |879         |
# +----------------------+---------+------------+
#
# 27
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |DEFk299pEBqKgUgQ703V9g|Glenn    |878         |
# +----------------------+---------+------------+
#
# 28
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |d7D4dYzF6THtOx9imf-wPw|Regina   |876         |
# +----------------------+---------+------------+
#
# 29
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |JUT0U3HTSB3kz9Wh7N0GqA|Corey    |875         |
# +----------------------+---------+------------+
#
# 30
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |m3qH3d97shbvSCtmUrpDFA|Melanie  |870         |
# +----------------------+---------+------------+
#
# 31
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |y94FS7iXvZp9QISUc0F__Q|renje    |869         |
# +----------------------+---------+------------+
#
# 32
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |JSukkufethSwEr-FGE3HKA|Anita    |867         |
# +----------------------+---------+------------+
#
# 33
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |mAqj8WY-uHncPpCn3ahCiA|Gregory  |866         |
# +----------------------+---------+------------+
#
# 34
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |L2JUm1kc8M3ji-Ud2HUBSw|Alexandra|863         |
# +----------------------+---------+------------+
# 35
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |vKUlUXLVylwdttu7h1_Y5Q|Travis   |862         |
# +----------------------+---------+------------+
#
# 36
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |q16FcvZyP5SURJEX8iGcTg|Angelica |862         |
# +----------------------+---------+------------+
#
# 37
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |EiP1OFgs-XGcKZux0OKWIA|Allison  |861         |
# +----------------------+---------+------------+
#
# 38
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CoS9VbTzh74Hh7FSlAKKVA|Elsa     |859         |
# +----------------------+---------+------------+
#
# 39
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |jqp5BEMzEUIWTCt6pezS2Q|Elle     |857         |
# +----------------------+---------+------------+
#
# 40
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |tjTrsF-CpDnTcclX-3sCTw|Al       |856         |
# +----------------------+---------+------------+
#
# 41
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |77Qa_ftGGDtTY7Ui3BFpiA|Virginia |855         |
# +----------------------+---------+------------+
#
# 42
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |mjOKUSdIqxFPSYMB-MmS9g|Greshka  |853         |
# +----------------------+---------+------------+
#
# 43
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |TbhyP24zYZqZ2VJZgu1wrg|Lauren   |852         |
# +----------------------+---------+------------+
#
# 44
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |GERRIWMslcP4-O6mLErPSQ|Melissa  |851         |
# +----------------------+---------+------------+
#
# 45
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |GXfrchFxdldoJXSEqUcdNw|Paul     |851         |
# +----------------------+---------+------------+
#
# 46
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |aUhcscNphAJQlZe1R_WRow|Vincci   |844         |
# +----------------------+---------+------------+
#
# 47
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |s6CB8sohXlCL6XZDgAy3SA|Cassandra|843         |
# +----------------------+---------+------------+
#
# 48
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |BeoFmNoFuz-h8uso-J2_lg|Jennifer |843         |
# +----------------------+---------+------------+
#
# 49
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |gNhNKOnQHDOElrtBohBt6Q|Joey     |842         |
# +----------------------+---------+------------+
#
# 50
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |p5eKzfGUZ7duXbDM0AM5bA|J        |841         |
# +----------------------+---------+------------+
#
# 51
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |KisZIfo92_OB_hMa7TvM5A|Sasha    |841         |
# +----------------------+---------+------------+
#
# 52
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |wHxDyAegrNiUzqXBKjAbvQ|Helen    |839         |
# +----------------------+---------+------------+
#
# 53
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |KFaUuuvfw-6rAbTzuYwU0g|Robert   |836         |
# +----------------------+---------+------------+
#
# 54
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |L7zPC6FjX72ITZaw_4D_ow|Krissy   |833         |
# +----------------------+---------+------------+
#
# 55
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |V4TPbscN8JsFbEFiwOVBKw|Mariko   |833         |
# +----------------------+---------+------------+
#
# 56
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |WPBrjBbk76ZtZQ8QpG09cQ|Henry    |832         |
# +----------------------+---------+------------+
#
# 57
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |G-1uSi0c5ZdvZBZJBZVCiA|Patrick  |831         |
# +----------------------+---------+------------+
#
# 58
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |_muhtS8ZFnV61s7Q4JXDwQ|Kevin    |831         |
# +----------------------+---------+------------+
#
# 59
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |wV4uhvJGok8nOR56Ex5mAg|Grace    |830         |
# +----------------------+---------+------------+
#
# 60
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |OnhM-m4MHhgWGiBWd9apYg|Nobody   |826         |
# +----------------------+---------+------------+
#
# 61
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Q8ATLre_I260dn2J1siM5Q|Yumiko   |825         |
# +----------------------+---------+------------+
#
# 62
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |2Od6rQYNvPUXQC2Go7vIqg|Catherine|823         |
# +----------------------+---------+------------+
#
# 63
# +----------------------+----------+------------+
# |user_id               |user_name |review_count|
# +----------------------+----------+------------+
# |zPNrEv30Piqoig3YG4en2g|DineoutGal|823         |
# +----------------------+----------+------------+
#
# 64
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |augJQotyLB503iq1gVJ_tg|Coy      |821         |
# +----------------------+---------+------------+
#
# 65
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |mKfW-Cv7JCsH4sWUpQ8sYA|Alena    |821         |
# +----------------------+---------+------------+
#
# 66
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |wSByVbwME4MzgkJaFyfvNg|Bryant   |819         |
# +----------------------+---------+------------+
#
# 67
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |jXIJnnyxXxizxNYEo2ze-A|Clara    |818         |
# +----------------------+---------+------------+
#
# 68
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |UtkjXTiMfGRz4R1zDF3Kxg|Susan    |817         |
# +----------------------+---------+------------+
# 69
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0FyfxrAMHm7AlrAkAXZQ9Q|Cyndi    |816         |
# +----------------------+---------+------------+
#
# 70
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |y8jJV4AeH6ZEBagQ_ys8KQ|Jenny    |814         |
# +----------------------+---------+------------+
#
# 71
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |C2uPDBzST_e1RBLDmgRtWg|Ross     |811         |
# +----------------------+---------+------------+
#
# 72
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CH9XhZWmcLYVAlzhwrhMvw|Jessica  |810         |
# +----------------------+---------+------------+
#
# 73
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CwgXzTGZOOI_8gA05aKM7Q|Michael  |809         |
# +----------------------+---------+------------+
#
# 74
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |rAAT39HF4khu-OdxBSr0jg|Mikey    |809         |
# +----------------------+---------+------------+
#
# 75
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |EBW16o-gGF1mzGC1LgjF_w|Thomas   |808         |
# +----------------------+---------+------------+
#
# 76
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |S0Pji5ZPQwlolC7vlq1lug|Kris     |805         |
# +----------------------+---------+------------+
#
# 77
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |310zgwPQRoe63E1pzzMVPA|Steve    |803         |
# +----------------------+---------+------------+
#
# 78
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |m_H93eDKdiBlRv8K7Ffgsg|Ben      |802         |
# +----------------------+---------+------------+
#
# 79
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |7SmEWHH-f7tYmRAwEBSceA|Valery   |800         |
# +----------------------+---------+------------+
#
# 80
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |j6Kv_wLQzZMWobLIyijX3A|John     |797         |
# +----------------------+---------+------------+
#
# 81
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |xFJ5Ja8y40CdMa1sfC4-gg|Hungry   |796         |
# +----------------------+---------+------------+
#
# 82
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |6AnWkbMbuYJ8BLupWTojrQ|Jade     |796         |
# +----------------------+---------+------------+
#
# 83
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |FlXBpK_YZxLo27jcMdII1w|Mallory  |795         |
# +----------------------+---------+------------+
#
# 84
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |MAatw6IQHYCqeATbHHMz1w|Melanio  |793         |
# +----------------------+---------+------------+
#
# 85
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |3S53VaMDPy8Lywk2TuPb4A|Mark     |790         |
# +----------------------+---------+------------+
#
# 86
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |njJjEOLRTo03Fwp4jg_Jpg|Tiffany  |788         |
# +----------------------+---------+------------+
#
# 87
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |IIwfcmU08iU_zLYEF0Qtjg|Christine|788         |
# +----------------------+---------+------------+
#
# 88
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |zsgH8afv2CDkn93jHtfBUQ|Linzi    |788         |
# +----------------------+---------+------------+
#
# 89
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |D4Eznn83MRWUK39n5WI0JA|Kelly    |784         |
# +----------------------+---------+------------+
#
# 90
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |QKbq76KuUHLRZjWXDtbwWQ|Jess     |784         |
# +----------------------+---------+------------+
#
# 91
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |yT_QCcnq-QGipWWuzIpvtw|Imran    |783         |
# +----------------------+---------+------------+
#
# 92
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0MeivhX0kZCfV3zMtHtk9Q|Charles  |780         |
# +----------------------+---------+------------+
#
# 93
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Xnqbsqex72_KYsOk4AbqDg|Rodrigo  |779         |
# +----------------------+---------+------------+
#
# 94
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |PRIiGqJFSx1G8rXPr8sryg|Jay      |777         |
# +----------------------+---------+------------+
#
# 95
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |GRfwtMaNbGLictaiaQnFhg|Ji       |776         |
# +----------------------+---------+------------+
#
# 96
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |CRLA264qZO-IxB2gQOnJmg|Athena   |776         |
# +----------------------+---------+------------+
#
# 97
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |_lqJfN8BVwl6wxfpzkaggg|Regina   |776         |
# +----------------------+---------+------------+
#
# 98
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |IKbjLnfBQtEyVzEu8CuOLg|Erica    |774         |
# +----------------------+---------+------------+
#
# 99
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |hKAelF9K5XSL9bjQO7PpIw|Suzee    |773         |
# +----------------------+---------+------------+
#
# 100
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |PvBmRN4suldo06Kcz2-vcw|Kevin    |773         |
# +----------------------+---------+------------+
#
# 101
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |IL4O2SIcumu1un5UkgB3FQ|Winston  |770         |
# +----------------------+---------+------------+
#
# 102
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |VnD9lZjizpOcioIJlTqQpQ|s        |770         |
# +----------------------+---------+------------+
# 103
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |_f9NyNygDasxm4x_8K0FMg|Jen      |770         |
# +----------------------+---------+------------+
#
# 104
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |HzoQKKHDq9BI37dyJAAtGA|Jim      |769         |
# +----------------------+---------+------------+
#
# 105
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |XVP0dQV-BsXKzp2KN214dg|Jess     |769         |
# +----------------------+---------+------------+
#
# 106
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |FSDj4JOrZxd5Z-ax15Klgg|Reyz     |768         |
# +----------------------+---------+------------+
#
# 107
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ZFAtjSBQDA3kDExHwFz4Iw|Jeff     |764         |
# +----------------------+---------+------------+
#
# 108
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |ZHqwFU0t1XGk7hZGjA-46Q|Ari      |760         |
# +----------------------+---------+------------+
#
# 109
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |oIxsWOWytMmV4bf_ffo01w|Candyce  |760         |
# +----------------------+---------+------------+
#
# 110
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |MpRMV1IlT8jzfLdI0fGr1w|Ben      |757         |
# +----------------------+---------+------------+
#
# 111
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |qtTd_VDFXoeNkJKrtQ4R2g|Evan     |756         |
# +----------------------+---------+------------+
#
# 112
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |YTdNcIWAt2nEzZ7NY-fniw|Jeff     |754         |
# +----------------------+---------+------------+
#
# 113
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |cctZ5e0OLd1g0jNdRk5Buw|Jewel    |754         |
# +----------------------+---------+------------+
#
# 114
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |SRSmzTPA2dX2Zpfa2uE4sA|Corey    |751         |
# +----------------------+---------+------------+
#
# 115
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |aomkMAGFrL-gD6cqQjB4bw|Johnson  |750         |
# +----------------------+---------+------------+
#
# 116
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |DgrIg1OR7arL8tVRiZ-psA|Robert   |750         |
# +----------------------+---------+------------+
#
# 117
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Kchj2U3yTo1hOZoiOkcErA|Tom      |749         |
# +----------------------+---------+------------+
#
# 118
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |fitXjNnwVB_HzqaBSrIGXQ|Victor   |745         |
# +----------------------+---------+------------+
#
# 119
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |Kj9cFO70zZOQorN0mgeLWA|Faiza    |745         |
# +----------------------+---------+------------+
#
# 120
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |r1sLj85JPwZ_KM2eviuLVg|Michael  |744         |
# +----------------------+---------+------------+
#
# 121
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |cSNER_qF_bb1t7kN0kZ44Q|Christina|744         |
# +----------------------+---------+------------+
#
# 122
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |jOU73K85NeMzBsqwJtfu0A|Thomas   |743         |
# +----------------------+---------+------------+
#
# 123
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |J3ucveGKKJDvtuCNnb_x0g|Faye     |741         |
# +----------------------+---------+------------+
#
# 124
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |C3Hpsx_eDfeSmxEc1HBzpA|Aaron    |740         |
# +----------------------+---------+------------+
#
# 125
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |HhfNSpdHGSGiuyi1anEOCQ|Jody     |739         |
# +----------------------+---------+------------+
#
# 126
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |BAo6ZQsIk9tpHn_Qi260DQ|Jaci     |739         |
# +----------------------+---------+------------+
#
# 127
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |vnpfnIsSFzInHaXgP4doLQ|Amy      |739         |
# +----------------------+---------+------------+
#
# 128
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |0pY1gYe_nyrBHhKex-nhgw|Brad     |739         |
# +----------------------+---------+------------+
#
# 129
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |QKhJkTpDuwnR6TozGT1eqg|Chris    |738         |
# +----------------------+---------+------------+
#
# 130
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |d31wiC8swpcod_WEbvT7ew|Amanda   |738         |
# +----------------------+---------+------------+
#
# 131
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |FBelk4JGoO0ZCFlfJzW3aQ|Jamie    |734         |
# +----------------------+---------+------------+
#
# 132
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |nr35WjC-YI0dFcsnW33Szw|Virginia |733         |
# +----------------------+---------+------------+
#
# 133
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |tXMMYZQgczzZPIIhfV7jhw|Danielle |732         |
# +----------------------+---------+------------+
#
# 134
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |xC-q_yh0XwcjRLimkS3RNg|Jonny    |730         |
# +----------------------+---------+------------+
#
# 135
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |nth2pi8IvNgx43Tntgq3ug|Joelle   |730         |
# +----------------------+---------+------------+
#
# 136
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |GYMIDghm2k7gSTpyKNid1Q|David    |729         |
# +----------------------+---------+------------+
# 137
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |1JtpcHELRrSDoWS80WtzuQ|Jon      |729         |
# +----------------------+---------+------------+
#
# 138
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |zzaq5Fn1U2Feut3dGxidNg|Marc     |727         |
# +----------------------+---------+------------+
#
# 139
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |-s48ZKSA31DFNcgJLChhQQ|Cynthia  |726         |
# +----------------------+---------+------------+
#
# 140
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |33h9Jv4VKbbxB42CUD9WQg|Wahed    |725         |
# +----------------------+---------+------------+
#
# 141
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |W7tKBCQ1XugMEDjB8ZBXqg|Angela   |725         |
# +----------------------+---------+------------+
#
# 142
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |pTc2Mf2ZW-VbZGfFI_VelQ|Nadine   |724         |
# +----------------------+---------+------------+
#
# 143
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |OrnQ04JCGie8Q2ymFF97FA|Michael  |724         |
# +----------------------+---------+------------+
#
# 144
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |VSINPig75DiGswnie1xxYA|Foodlover|724         |
# +----------------------+---------+------------+
#
# 145
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |7BiWqhSJ-h0drMp7xCZC8w|Lily     |724         |
# +----------------------+---------+------------+
#
# 146
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |z3n4lF8oWYahp-3Hx56d7A|Kevin    |723         |
# +----------------------+---------+------------+
#
# 147
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |YrlNGnrofZHseVYxrLrvJA|Miriam   |715         |
# +----------------------+---------+------------+
#
# 148
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |UcRcib_NrrV2cznsgqoFZQ|Traci    |715         |
# +----------------------+---------+------------+
#
# 149
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |thqNHm0GQe1Bn8LmRSWddA|Joseph   |715         |
# +----------------------+---------+------------+
#
# 150

# %%
##### Load similar users file produced from above code cell
import pickle
with open("sim_users_200.txt", "rb") as fp:   # Unpickling
    sim_users_all = pickle.load(fp)

# %%
sim_users_all.head()
# Out:
#             input_user_id                 user_id  user_name     score  \
# 9  -3s52C4zL_DHRK0ULG6qtg  ZlWvLV9xLBCMzow7otGeEA      Barry  0.825380
# 7  -3s52C4zL_DHRK0ULG6qtg  dsqeMUrkQZ80jfMgf0jszw       Lola  0.822470
# 6  -3s52C4zL_DHRK0ULG6qtg  FnzXRHWUl10fKq026BGGFQ  Constanza  0.823784
# 5  -3s52C4zL_DHRK0ULG6qtg  sbthWXD2VHV_jlPSRWn7RA      Laura  0.822960
# 4  -3s52C4zL_DHRK0ULG6qtg  ZDmizf31m6E5-rzE6OiGLg   Marianne  0.823582
#
#   review_count
# 9            3
# 7           30
# 6           14
# 5           20
# 4           18

# %%
sim_users_all.shape
# Out:
# (2050, 5)

# %%
merged_100 = pd.DataFrame(columns = ['business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y'])

for i in range(len(sim_users_all)):
    review_uid1 = review.loc[review['user_id'].isin([sim_users_all.input_user_id.iloc[i]])] 
    review_uid2 = review.loc[review['user_id'].isin([sim_users_all.user_id.iloc[i]])] 
    merged = pd.merge(review_uid1, review_uid2, how = 'inner', on = 'business_id')
    merged = merged[['user_id_x', 'user_id_y', 'business_id', 'stars_x', 'stars_y', 'text_x', 'text_y', 'date_x', 'date_y']]
    merged_100 = pd.concat([merged_100, merged])
    
with open("user_simil_business_ratings.txt", "wb") as fp:   #Pickling
    pickle.dump(merged_100, fp)

merged_100.to_csv("user_simil_business_ratings_250_400.csv")

# %%
# use this similarity matrix, recommend highly rated businesses from similar users
# high similarity can be seen, even if they have not reviewed a business in common.
# using similar model of users for businesses, can identify highly similar businesses
    # these businesses can be similar in ratings, category of business

# %% [markdown]
# ####### To compare with Ahmed's similarity measurements

# %%
# test with user

uids = ['J5Eb7LhJaOa20k0ppcOCOg']

print('\ninput user details:')
user_df.select('user_id','user_name', 'review_count') \
    .filter(user_df.user_id.isin(uids) == True).show(truncate=False)
    
# get top 10 similar users
sim_users = getUserDetails(getSimilarUsers(uids, all_user_vecs, 200))

print('Top 10 similar Users for each input restaurant are:"')
sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas()
# Out:
# input user details:
# +----------------------+---------+------------+
# |user_id               |user_name|review_count|
# +----------------------+---------+------------+
# |J5Eb7LhJaOa20k0ppcOCOg|Alek     |34          |
# +----------------------+---------+------------+
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
# Top 10 similar Users for each input restaurant are:"
#               input_user_id                 user_id     user_name     score  \
# 0    J5Eb7LhJaOa20k0ppcOCOg  vtoiZ0SFtO51-xvEVTdIYQ         David  0.942662
# 1    J5Eb7LhJaOa20k0ppcOCOg  iwDP-y8NJG3Vem2z242LDg  CalamityJane  0.938837
# 2    J5Eb7LhJaOa20k0ppcOCOg  Np-Eumi0cPgX7S2LWOC57A       Rebecca  0.935694
# 3    J5Eb7LhJaOa20k0ppcOCOg  5InzuFd9Kq6uk22a3DIfgQ         Kelly  0.935056
# 4    J5Eb7LhJaOa20k0ppcOCOg  qZa2urX00YWHs-jRcWgUqw         Silas  0.932498
# 5    J5Eb7LhJaOa20k0ppcOCOg  Tbr5YHoLq1IlP1QkNZ2EeA            B.  0.931331
# 6    J5Eb7LhJaOa20k0ppcOCOg  nXehm6zt294ZswIgh5LpbA       Brandon  0.943381
# 7    J5Eb7LhJaOa20k0ppcOCOg  Eb6TPevViIzBy8ApjPtuqw          Inae  0.929516
# 8    J5Eb7LhJaOa20k0ppcOCOg  k9iqO8atK7BC4f8RcSXi-g        Esther  0.935531
# 9    J5Eb7LhJaOa20k0ppcOCOg  SkpCulULgiBfLc4lV8vx2g     Stephanie  0.936608
# 10   J5Eb7LhJaOa20k0ppcOCOg  mFwRTTDW0Yr-rFkTF2cFsw          Mike  0.932204
# 11   J5Eb7LhJaOa20k0ppcOCOg  BNKWo55_3v5WNUgj-hsDZg        Graeme  0.950331
# 12   J5Eb7LhJaOa20k0ppcOCOg  MfWGWVuUo9bptZ9VcQTC5Q       Zachary  0.935771
# 13   J5Eb7LhJaOa20k0ppcOCOg  -d2daWmftYumOaYpbD5D8Q           Jia  0.929861
# 14   J5Eb7LhJaOa20k0ppcOCOg  Oxe8DXjBOi6C-cR2w64zOg          Izzy  0.948715
# 15   J5Eb7LhJaOa20k0ppcOCOg  KnkiyXZDt8hVdq_kw1iWuw          Thom  0.938173
# 16   J5Eb7LhJaOa20k0ppcOCOg  GRQc_7_6xPD5Rb9PakUEKw       Bradley  0.939978
# 17   J5Eb7LhJaOa20k0ppcOCOg  CA1N8B5ZkSiUJeOXYcWImg           Amy  0.936007
# 18   J5Eb7LhJaOa20k0ppcOCOg  7G76_EmnZzpIdVlom77U9g           Yav  0.932213
# 19   J5Eb7LhJaOa20k0ppcOCOg  x9QBX-kF2AC6UmywqmREcg        Nathan  0.932335
# 20   J5Eb7LhJaOa20k0ppcOCOg  7vsMC2RndD2WertWHA5GJQ         Lexie  0.934053
# 21   J5Eb7LhJaOa20k0ppcOCOg  CdUZIzSe0GJ7qxq4BU8pQw         Jonas  0.932381
# 22   J5Eb7LhJaOa20k0ppcOCOg  YGtYQQbFhb0I2O_xNl_Icw            M.  0.930116
# 23   J5Eb7LhJaOa20k0ppcOCOg  DtPW4KOuNxq0sdb6Tvy-ag         Erica  0.938848
# 24   J5Eb7LhJaOa20k0ppcOCOg  UxTh0zFCbHj2PDxDa0aikQ       Michael  0.942401
# 25   J5Eb7LhJaOa20k0ppcOCOg  VnKj044Tt5doqaVDIJbWsw           Ian  0.930042
# 26   J5Eb7LhJaOa20k0ppcOCOg  uyEIiUd0qGkZySz4kbA0uQ             D  0.938943
# 27   J5Eb7LhJaOa20k0ppcOCOg  StCSYeJ1I-G1LbdpW65kGQ         Shyni  0.937318
# 28   J5Eb7LhJaOa20k0ppcOCOg  UYR__5SkmsvBNP9lMfki6A        Kirsty  0.937998
# 29   J5Eb7LhJaOa20k0ppcOCOg  fjNNUJS0dtMr7W0hHMiNVw         Diego  0.932808
# ..                      ...                     ...           ...       ...
# 170  J5Eb7LhJaOa20k0ppcOCOg  raWHBzo-7sFowVvMd2OwOQ           Lev  0.940033
# 171  J5Eb7LhJaOa20k0ppcOCOg  Rp-cSUHm-EKBxgBS73PNNg          Thuy  0.933994
# 172  J5Eb7LhJaOa20k0ppcOCOg  UWXdAdrZi5I4RB2RHZesuw         Alida  0.935849
# 173  J5Eb7LhJaOa20k0ppcOCOg  0mixFm6PjDxD87enK0Jddg            LJ  0.948459
# 174  J5Eb7LhJaOa20k0ppcOCOg  D4Kmr1x6myjxSYXo9Xcpmw          Jane  0.938298
# 175  J5Eb7LhJaOa20k0ppcOCOg  KmHtoogKhK-ID7FWGOPvag       Vanessa  0.930972
# 176  J5Eb7LhJaOa20k0ppcOCOg  yK6wyLZ2I66B5-MJcS88xg          Nick  0.930301
# 177  J5Eb7LhJaOa20k0ppcOCOg  fcfFXPoxpLHvR98cvf618A       Michael  0.934509
# 178  J5Eb7LhJaOa20k0ppcOCOg  KlTLXLm_rnAUkYyvD1pnBA       Richard  0.937930
# 179  J5Eb7LhJaOa20k0ppcOCOg  S5pJIRcK5_4C6MxwieuGIQ        Chelle  0.937438
# 180  J5Eb7LhJaOa20k0ppcOCOg  UzhbEOOqmbINTJo6K9PH_Q        Monica  0.934365
# 181  J5Eb7LhJaOa20k0ppcOCOg  Kf10dTiGlcnyhj8DBoZn1A           Nav  0.943942
# 182  J5Eb7LhJaOa20k0ppcOCOg  ZrN6jjXI41GP7Oieae6CNQ        Andrew  0.941385
# 183  J5Eb7LhJaOa20k0ppcOCOg  Z06B0N794eSdQ_U8kx19DA          John  0.934548
# 184  J5Eb7LhJaOa20k0ppcOCOg  esxOax4RnP5tcflaJlhjUg       Melanie  0.928968
# 185  J5Eb7LhJaOa20k0ppcOCOg  ImBb4MxG9wfTkZfOcfZhJQ        Andrew  0.958846
# 186  J5Eb7LhJaOa20k0ppcOCOg  88v0geHUmMkAr1uIeKogew    Karin Kara  0.948447
# 187  J5Eb7LhJaOa20k0ppcOCOg  8qY0rSk-AUtCAl8th4ru2A             M  0.933967
# 188  J5Eb7LhJaOa20k0ppcOCOg  m7z-tX6XDZ27xGhGjnI21w          Tiff  0.932136
# 189  J5Eb7LhJaOa20k0ppcOCOg  qJZCiO3qSOygLLxzX8l1wg           Tim  0.932214
# 190  J5Eb7LhJaOa20k0ppcOCOg  WyodjvNUVta-zO7Ij0TvVw      Stefanie  0.941700
# 191  J5Eb7LhJaOa20k0ppcOCOg  44LbLRmc0FsXYJhQ6nz3Vw       Maureen  0.933678
# 192  J5Eb7LhJaOa20k0ppcOCOg  0najbLIinR5v6GmI2Nlcsw           Amy  0.955133
# 193  J5Eb7LhJaOa20k0ppcOCOg  TGrZk61ja7X1ijAGW5lNmg        Renato  0.959045
# 194  J5Eb7LhJaOa20k0ppcOCOg  si6C5GKofPIN-NpdWMO7nw        Kenzie  0.933197
# 195  J5Eb7LhJaOa20k0ppcOCOg  e3zojPmUy-2vW48PWn7Fpw          Rowy  0.934960
# 196  J5Eb7LhJaOa20k0ppcOCOg  aM2vN1DjTI41VPRIroZ7lw        Tamara  0.938858
# 197  J5Eb7LhJaOa20k0ppcOCOg  dRzgWKHQonRy4vHxbUxE5Q           Jim  0.932845
# 198  J5Eb7LhJaOa20k0ppcOCOg  MMeicSIVYTzJVUIxcGqHlA     Christina  0.930736
# 199  J5Eb7LhJaOa20k0ppcOCOg  0qA24lu9d-NtCdSaNPc4lw      Michelle  0.932130
#
#      review_count
# 0              44
# 1              89
# 2              24
# 3              40
# 4              73
# 5              33
# 6             148
# 7              24
# 8              42
# 9             374
# 10            320
# 11             48
# 12             73
# 13            235
# 14            218
# 15            220
# 16             71
# 17            173
# 18             20
# 19              4
# 20             45
# 21            133
# 22             29
# 23             59
# 24             53
# 25            487
# 26             48
# 27            111
# 28             43
# 29            127
# ..            ...
# 170            16
# 171           145
# 172            37
# 173            44
# 174            53
# 175           144
# 176           285
# 177           126
# 178           175
# 179            53
# 180            93
# 181           146
# 182           191
# 183            22
# 184            35
# 185           158
# 186            49
# 187            75
# 188           530
# 189           180
# 190            34
# 191           124
# 192            26
# 193           127
# 194            23
# 195            41
# 196            96
# 197           133
# 198            21
# 199            68
#
# [200 rows x 5 columns]

# %%
sim_users.select('input_user_id', 'a.user_id', 'user_name', 'score','review_count').toPandas().sort_values(by = 'input_user_id')
# Out:
#              input_user_id                 user_id user_name     score  \
# 19  CxDOIDnH8gp9KXzpBHJYXw  ma6206bmu-a_Ja7Iv-yRCw    Sharon  0.953301
# 2   CxDOIDnH8gp9KXzpBHJYXw  DNlzbI54zCOa4to-vTWBJQ     Karen  0.956598
# 16  CxDOIDnH8gp9KXzpBHJYXw  4D6LLuJfao_eHGA6XZR-bA    Jackie  0.951405
# 15  CxDOIDnH8gp9KXzpBHJYXw  QPJJohtGqkMkaN0Gt3TRIg   Cherrie  0.954686
# 5   CxDOIDnH8gp9KXzpBHJYXw  xC-q_yh0XwcjRLimkS3RNg     Jonny  0.954941
# 14  CxDOIDnH8gp9KXzpBHJYXw  LQG9wFTmscbAATp8QWj1hg     Kathy  0.956582
# 7   CxDOIDnH8gp9KXzpBHJYXw  IhjiCSCiaefHE-4FAvSOkA    Janice  0.957189
# 8   CxDOIDnH8gp9KXzpBHJYXw  Wu0yySWcHQ5tZ_59HNiamg     WaYnE  0.960825
# 13  CxDOIDnH8gp9KXzpBHJYXw  KBh4r16e9Grc1HI9pG4wTg    Rainie  0.953038
# 12  CxDOIDnH8gp9KXzpBHJYXw  vZEY5WEJ9sRxTGhm97132A  Adrienne  0.951509
# 17  Tjv5bBtJ-Z_CLiY-rheG2g  EgotOxec2MuH4xvIv_KRIA    Nabila  0.969768
# 0   Tjv5bBtJ-Z_CLiY-rheG2g  sWKaLjpYG6VABf23CXDhyA   Jasmine  0.966809
# 10  Tjv5bBtJ-Z_CLiY-rheG2g  J3ucveGKKJDvtuCNnb_x0g      Faye  0.976529
# 18  Tjv5bBtJ-Z_CLiY-rheG2g  ys-6BWxpS1BpUkHZA9oLqQ    Vivian  0.971924
# 6   Tjv5bBtJ-Z_CLiY-rheG2g  20xtru4h_7TjFn4lSHmSsg      Maia  0.964414
# 4   Tjv5bBtJ-Z_CLiY-rheG2g  pVj37cy4Y6FfH9YIlEhsZA    Grayce  0.966964
# 3   Tjv5bBtJ-Z_CLiY-rheG2g  VK5wB63rEMb5Hp-9OCPs1g      Anna  0.966507
# 1   Tjv5bBtJ-Z_CLiY-rheG2g  dSTRQSeCqMTbs7l8KF_xJg   Arielle  0.964194
# 11  Tjv5bBtJ-Z_CLiY-rheG2g  PGx4HvY5joEeqXzam6tO7A      Lisa  0.962631
# 9   Tjv5bBtJ-Z_CLiY-rheG2g  Yl7OYdHuYmr7K-IW9_ayng     Alana  0.964111
#
#     review_count
# 19           232
# 2            395
# 16           219
# 15           235
# 5            730
# 14           501
# 7             59
# 8           1083
# 13           450
# 12            64
# 17           249
# 0            284
# 10           741
# 18            98
# 6            137
# 4            153
# 3             76
# 1            167
# 11           349
# 9            304
